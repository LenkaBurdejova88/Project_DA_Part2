# %% [markdown]
# ### Insert columns
#
# * Insert column year
#
# * Insert missing columns
#
# * Rearragement of column order

# %%
import pandas as pd #import pandas

import numpy as np

df21 = pd.read_csv("df21_final_headers.csv") #read csv

df21
# Out:
#          Age Gender                   Country          Education  \
# 0      50-54    Man                     India  Bachelor’s degree
# 1      50-54    Man                     Other    Master’s degree
# 2      22-24    Man                  Pakistan    Master’s degree
# 3      45-49    Man                     Other    Doctoral degree
# 4      45-49    Man                     India    Doctoral degree
# ...      ...    ...                       ...                ...
# 25968  30-34    Man                     Other  Bachelor’s degree
# 25969  22-24    Man                     Other    Master’s degree
# 25970  50-54    Man                     Other    Doctoral degree
# 25971  45-49    Man  United States of America    Master’s degree
# 25972  18-21    Man                     India  Bachelor’s degree
#
#                   Current_Role          Time_Writing_Code  \
# 0                        Other                 5-10 years
# 1      Program/Project Manager                  20+ years
# 2            Software Engineer                  1-3 years
# 3           Research Scientist                  20+ years
# 4                        Other                  < 1 years
# ...                        ...                        ...
# 25968             Data Analyst                  1-3 years
# 25969                  Student                  1-3 years
# 25970       Research Scientist  I have never written code
# 25971           Data Scientist                 5-10 years
# 25972         Business Analyst  I have never written code
#
#       Programming_Languages_Python Programming_Languages_R  \
# 0                           Python                       R
# 1                              NaN                     NaN
# 2                           Python                     NaN
# 3                           Python                     NaN
# 4                           Python                     NaN
# ...                            ...                     ...
# 25968                       Python                     NaN
# 25969                       Python                     NaN
# 25970                          NaN                     NaN
# 25971                       Python                     NaN
# 25972                          NaN                     NaN
#
#       Programming_Languages_SQL Programming_Languages_C  ...  \
# 0                           NaN                     NaN  ...
# 1                           SQL                       C  ...
# 2                           NaN                     NaN  ...
# 3                           NaN                     NaN  ...
# 4                           NaN                       C  ...
# ...                         ...                     ...  ...
# 25968                       SQL                     NaN  ...
# 25969                       NaN                     NaN  ...
# 25970                       NaN                     NaN  ...
# 25971                       SQL                     NaN  ...
# 25972                       NaN                     NaN  ...
#
#       Data_Science_Courses_Datacamp Data_Science_Courses_Fast.Ai  \
# 0                          DataCamp                          NaN
# 1                               NaN                          NaN
# 2                          DataCamp                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 25968                      DataCamp                          NaN
# 25969                           NaN                          NaN
# 25970                           NaN                          NaN
# 25971                           NaN                          NaN
# 25972                           NaN                          NaN
#
#       Data_Science_Courses_Udacity Data_Science_Courses_Udemy  \
# 0                          Udacity                      Udemy
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                      Udemy
# ...                            ...                        ...
# 25968                      Udacity                      Udemy
# 25969                          NaN                        NaN
# 25970                          NaN                        NaN
# 25971                          NaN                        NaN
# 25972                          NaN                        NaN
#
#       Data_Science_Courses_Linkedin_Learning  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 25968                      LinkedIn Learning
# 25969                                    NaN
# 25970                      LinkedIn Learning
# 25971                                    NaN
# 25972                                    NaN
#
#        Data_Science_Courses_Cloud_Certification_Programs  \
# 0                                                    NaN
# 1      Cloud-certification programs (direct from AWS,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25968  Cloud-certification programs (direct from AWS,...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
#
#                  Data_Science_Courses_University_Courses  \
# 0                                                    NaN
# 1      University Courses (resulting in a university ...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25968                                                NaN
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
#
#        Data_Science_Courses_None Data_Science_Courses_Other  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 25968                        NaN                        NaN
# 25969                        NaN                        NaN
# 25970                        NaN                        NaN
# 25971                        NaN                        NaN
# 25972                        NaN                        NaN
#
#                      Primary_Tool_Used_For_Data_Analysis
# 0      Local development environments (RStudio, Jupyt...
# 1        Advanced statistical software (SPSS, SAS, etc.)
# 2      Basic statistical software (Microsoft Excel, G...
# 3      Local development environments (RStudio, Jupyt...
# 4      Local development environments (RStudio, Jupyt...
# ...                                                  ...
# 25968  Business intelligence software (Salesforce, Ta...
# 25969                                                NaN
# 25970  Basic statistical software (Microsoft Excel, G...
# 25971                                                NaN
# 25972    Advanced statistical software (SPSS, SAS, etc.)
#
# [25973 rows x 100 columns]

# %% [markdown]
# Insert column Year 2021

# %%
df21.insert(0, "Year", 2021)

df21
# Out:
#        Year    Age Gender                   Country          Education  \
# 0      2021  50-54    Man                     India  Bachelor’s degree
# 1      2021  50-54    Man                     Other    Master’s degree
# 2      2021  22-24    Man                  Pakistan    Master’s degree
# 3      2021  45-49    Man                     Other    Doctoral degree
# 4      2021  45-49    Man                     India    Doctoral degree
# ...     ...    ...    ...                       ...                ...
# 25968  2021  30-34    Man                     Other  Bachelor’s degree
# 25969  2021  22-24    Man                     Other    Master’s degree
# 25970  2021  50-54    Man                     Other    Doctoral degree
# 25971  2021  45-49    Man  United States of America    Master’s degree
# 25972  2021  18-21    Man                     India  Bachelor’s degree
#
#                   Current_Role          Time_Writing_Code  \
# 0                        Other                 5-10 years
# 1      Program/Project Manager                  20+ years
# 2            Software Engineer                  1-3 years
# 3           Research Scientist                  20+ years
# 4                        Other                  < 1 years
# ...                        ...                        ...
# 25968             Data Analyst                  1-3 years
# 25969                  Student                  1-3 years
# 25970       Research Scientist  I have never written code
# 25971           Data Scientist                 5-10 years
# 25972         Business Analyst  I have never written code
#
#       Programming_Languages_Python Programming_Languages_R  \
# 0                           Python                       R
# 1                              NaN                     NaN
# 2                           Python                     NaN
# 3                           Python                     NaN
# 4                           Python                     NaN
# ...                            ...                     ...
# 25968                       Python                     NaN
# 25969                       Python                     NaN
# 25970                          NaN                     NaN
# 25971                       Python                     NaN
# 25972                          NaN                     NaN
#
#       Programming_Languages_SQL  ... Data_Science_Courses_Datacamp  \
# 0                           NaN  ...                      DataCamp
# 1                           SQL  ...                           NaN
# 2                           NaN  ...                      DataCamp
# 3                           NaN  ...                           NaN
# 4                           NaN  ...                           NaN
# ...                         ...  ...                           ...
# 25968                       SQL  ...                      DataCamp
# 25969                       NaN  ...                           NaN
# 25970                       NaN  ...                           NaN
# 25971                       SQL  ...                           NaN
# 25972                       NaN  ...                           NaN
#
#       Data_Science_Courses_Fast.Ai Data_Science_Courses_Udacity  \
# 0                              NaN                      Udacity
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 25968                          NaN                      Udacity
# 25969                          NaN                          NaN
# 25970                          NaN                          NaN
# 25971                          NaN                          NaN
# 25972                          NaN                          NaN
#
#       Data_Science_Courses_Udemy Data_Science_Courses_Linkedin_Learning  \
# 0                          Udemy                                    NaN
# 1                            NaN                                    NaN
# 2                            NaN                                    NaN
# 3                            NaN                                    NaN
# 4                          Udemy                                    NaN
# ...                          ...                                    ...
# 25968                      Udemy                      LinkedIn Learning
# 25969                        NaN                                    NaN
# 25970                        NaN                      LinkedIn Learning
# 25971                        NaN                                    NaN
# 25972                        NaN                                    NaN
#
#        Data_Science_Courses_Cloud_Certification_Programs  \
# 0                                                    NaN
# 1      Cloud-certification programs (direct from AWS,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25968  Cloud-certification programs (direct from AWS,...
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
#
#                  Data_Science_Courses_University_Courses  \
# 0                                                    NaN
# 1      University Courses (resulting in a university ...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25968                                                NaN
# 25969                                                NaN
# 25970                                                NaN
# 25971                                                NaN
# 25972                                                NaN
#
#       Data_Science_Courses_None  Data_Science_Courses_Other  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 25968                       NaN                         NaN
# 25969                       NaN                         NaN
# 25970                       NaN                         NaN
# 25971                       NaN                         NaN
# 25972                       NaN                         NaN
#
#                      Primary_Tool_Used_For_Data_Analysis
# 0      Local development environments (RStudio, Jupyt...
# 1        Advanced statistical software (SPSS, SAS, etc.)
# 2      Basic statistical software (Microsoft Excel, G...
# 3      Local development environments (RStudio, Jupyt...
# 4      Local development environments (RStudio, Jupyt...
# ...                                                  ...
# 25968  Business intelligence software (Salesforce, Ta...
# 25969                                                NaN
# 25970  Basic statistical software (Microsoft Excel, G...
# 25971                                                NaN
# 25972    Advanced statistical software (SPSS, SAS, etc.)
#
# [25973 rows x 101 columns]

# %% [markdown]
# Insert missing columns
#
# * list of missing columns from df18-21_missing_columns.ipynb

# %%
missing_columns_text="""
Programming_Languages_C#
Machine_Learning_Frameworks_Spark_Mllib
Programming_Languages_Visual_Basic
Data_Visualization_Libraries_Lattice
Notebook_Products_Domino_Datalab
Programming_Languages_Vba
Machine_Learning_Frameworks_Cntk
Data_Science_Courses_Developers.Google.Com
Ide's_nteract
Machine_Learning_Frameworks_Mlr
Notebook_Products_Aws_Notebook
Programming_Languages_Typescript
Data_Science_Courses_Dataquest
Programming_Languages_Scala
Programming_Languages_Ruby
Programming_Languages_.Net
Machine_Learning_Frameworks_Caffe
Programming_Languages_Sas
Programming_Languages_Go
Ide's_IntelliJ
Programming_Languages_Php
Ide's_Atom
Machine_Learning_Frameworks_Randomforest
Notebook_Products_Crestle
Notebook_Products_Floydhub
Programming_Languages_Stata
Data_Science_Courses_Theschool.Ai"""

missing_columns = missing_columns_text.strip().splitlines()

print(missing_columns)

len(missing_columns)
# Out:
# ['Programming_Languages_C#', 'Machine_Learning_Frameworks_Spark_Mllib', 'Programming_Languages_Visual_Basic', 'Data_Visualization_Libraries_Lattice', 'Notebook_Products_Domino_Datalab', 'Programming_Languages_Vba', 'Machine_Learning_Frameworks_Cntk', 'Data_Science_Courses_Developers.Google.Com', "Ide's_nteract", 'Machine_Learning_Frameworks_Mlr', 'Notebook_Products_Aws_Notebook', 'Programming_Languages_Typescript', 'Data_Science_Courses_Dataquest', 'Programming_Languages_Scala', 'Programming_Languages_Ruby', 'Programming_Languages_.Net', 'Machine_Learning_Frameworks_Caffe', 'Programming_Languages_Sas', 'Programming_Languages_Go', "Ide's_IntelliJ", 'Programming_Languages_Php', "Ide's_Atom", 'Machine_Learning_Frameworks_Randomforest', 'Notebook_Products_Crestle', 'Notebook_Products_Floydhub', 'Programming_Languages_Stata', 'Data_Science_Courses_Theschool.Ai']
# 27

# %%
#fill bullets with NaN

for column in missing_columns:
    df21[column] = np.nan

# check all columns
df21.to_csv("df21_col_complete.csv", index=False)

# %% [markdown]
# Rearrangement of column order

# %%
first_columns = ["Year", "Age", "Country", "Education", "Gender",
                 "Current_Role","Current_Yearly_Compensation", "Time_Writing_Code",
                  "Time_Using_Machine_Learning_Methods",
                  "Primary_Tool_Used_For_Data_Analysis"]

# all columns in df
all_columns = df21.columns.tolist()

# columns which aren't in first_columns
residue = sorted([col for col in all_columns if col not in first_columns])

# new order
new_order = first_columns + residue

# print(new_order)

#rearrangement of columns in df
df21 = df21[new_order]

#save as csv file
df21.to_csv("df21_all_col.csv", index=False)
